# %%
import customtkinter
import time
from PIL import Image

customtkinter.set_appearance_mode("dark")
customtkinter.set_default_color_theme("blue")

# %%
root = customtkinter.CTkToplevel()
root.title("Portlogics")
root.grid()
root.geometry("1920x1080")

root.columnconfigure(0, weight=1)
root.columnconfigure((1,2), weight=2)
root.rowconfigure(0, weight=1)
root.rowconfigure(1, weight=1)
root.rowconfigure(2, weight=3)
root.rowconfigure(3, weight=3)
# root.rowconfigure(1, weight=1)

root.config(pady=10, padx=10)

# Image
image_1 = customtkinter.CTkImage(dark_image=Image.open(r"E:\Internship\Common_resources\official_train_img\images\images\1-122700001-OCR-LF-C01.jpg"), size=(690, 400))
image_2 = customtkinter.CTkImage(dark_image=Image.open(r"E:\Internship\Common_resources\official_train_img\images\images\1-123053001-OCR-AS-B01.jpg"), size=(600, 350))

tlframe = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
tlframe.grid(row=0, column=0, columnspan=1, rowspan=1, pady=5, padx=5, sticky="nsew")

# status_label = customtkinter.CTkLabel(root, width=400, height=1)
tlframe = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
tlframe.grid(row=0, column=0, columnspan=1, rowspan=1, pady=5, padx=5, sticky="nsew")
tlframe.rowconfigure((0,1), weight=1)
tlframe.columnconfigure(0, weight=1)
tlframe.columnconfigure(1, weight=2)

status_label = customtkinter.CTkLabel(tlframe, text='STATUS', width=100, height=50, bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
status_label.grid(row=0, column=0, padx=5, pady=5, sticky="nsew")

status_display = customtkinter.CTkLabel(tlframe, text='TRUCK DETECTED', width=300, height=50, bg_color='#ffffff', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"), text_color='black')
status_display.grid(row=0, column=1, padx=5, pady=5, sticky="nsew")

license_plate = customtkinter.CTkLabel(tlframe, text='PLATE', width=100, height=50, bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
license_plate.grid(row=1, column=0, padx=5, pady=5, sticky="nsew")

plate_display = customtkinter.CTkLabel(tlframe, text='15C16188', width=300, height=50, bg_color='#ffffff', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"), text_color='black')
plate_display.grid(row=1, column=1, padx=5, pady=5, sticky="nsew")

blframe = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
blframe.grid(row=1, column=0, columnspan=1, rowspan=3, pady=5, padx=5, sticky="nsew")
blframe.rowconfigure((0,1), weight=1)
blframe.columnconfigure((0,1), weight=1)

# Showing container 1 details
c1_frame = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
c1_frame.grid(row=0, column=1, rowspan=2, pady=5, padx=5, sticky="new")
c1_frame.rowconfigure(0, weight=2)
c1_frame.rowconfigure(1, weight=4)
# c1_frame.rowconfigure(2, weight=4)
c1_frame.columnconfigure(0, weight=1)

c1_label = customtkinter.CTkLabel(c1_frame, text='FRONT', text_color='blue', bg_color= '#99aab5', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
c1_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")

c1_image = customtkinter.CTkLabel(c1_frame, image=image_1, bg_color= '#7289da')
c1_image.grid(row=1, column=0, padx=5, pady=5, sticky="n")

# c1_detail = customtkinter.CTkLabel(c1_frame, text='DETAILS', bg_color= '#2c2f33', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
# c1_detail.grid(row=2, column=0, padx=5, pady=5, sticky="n")

# Showing container 2 details
c2_frame = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
c2_frame.grid(row=0, column=2, rowspan=2, pady=5, padx=5, sticky="new")
c2_frame.rowconfigure(0, weight=2)
c2_frame.rowconfigure(1, weight=4)
c2_frame.columnconfigure(0, weight=1)

c2_label = customtkinter.CTkLabel(c2_frame, text='BACK', text_color='blue', bg_color= '#99aab5', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
c2_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")

c2_image = customtkinter.CTkLabel(c2_frame, image=image_1, bg_color= '#7289da')
c2_image.grid(row=1, column=0, padx=5, pady=5, sticky="n")

# c2_detail = customtkinter.CTkLabel(c2_frame, text='DETAILS', bg_color= '#2c2f33', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
# c2_detail.grid(row=2, column=0, padx=5, pady=5, sticky="n")

# Showing container 3 details
c3_frame = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
c3_frame.grid(row=2, column=1, rowspan=2, pady=5, padx=5, sticky="nsew")
c3_frame.rowconfigure(0, weight=2)
c3_frame.rowconfigure(1, weight=4)
c3_frame.columnconfigure(0, weight=1)

c3_label = customtkinter.CTkLabel(c3_frame, text='CONTAINER 1', text_color='blue', bg_color= '#99aab5', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
c3_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")

c3_image = customtkinter.CTkLabel(c3_frame, image=image_1, bg_color= '#7289da')
c3_image.grid(row=1, column=0, padx=5, pady=5, sticky="n")

c3_detail = customtkinter.CTkLabel(c3_frame, text='DETAILS', bg_color= '#2c2f33', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
c3_detail.grid(row=2, column=0, padx=5, pady=5, sticky="n")

# Showing container 4 details
c4_frame = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
c4_frame.grid(row=2, column=2, rowspan=2, pady=5, padx=5, sticky="nsew")
c4_frame.rowconfigure(0, weight=1)
c4_frame.rowconfigure(1, weight=3)
c4_frame.rowconfigure(2, weight=3)
c4_frame.columnconfigure(0, weight=1)


c4_image = customtkinter.CTkLabel(c4_frame, image=image_1, bg_color= '#7289da')
c4_image.grid(row=1, column=0, padx=5, pady=0, sticky="n")

c4_label = customtkinter.CTkLabel(c4_image, text='CONTAINER 2', text_color='blue', bg_color= '#99aab5', corner_radius=20, font=customtkinter.CTkFont(size=15, weight="bold"))
# c4_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")
c4_label.place(relx=0, rely=1, x=-1, y=0,anchor="sw")

c4_detail = customtkinter.CTkLabel(c4_frame, text='DETAILS', bg_color= '#2c2f33', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
c4_detail.grid(row=2, column=0, padx=5, pady=5, sticky="n")

root.mainloop()

# %%
root = customtkinter.CTkToplevel()
root.title("Portlogics")
root.grid()
root.geometry("1920x1080")

root.columnconfigure(0, weight=1)
root.columnconfigure(1, weight=4)
root.columnconfigure(2, weight=4)
# root.rowconfigure(0, weight=1)
root.rowconfigure(1, weight=1)
# root.rowconfigure(2, weight=3)
# root.rowconfigure(3, weight=3)
# root.rowconfigure(1, weight=1)

root.config(pady=10, padx=10)

# Top banner
tframe = customtkinter.CTkFrame(root, height=30, fg_color='transparent')
tframe.grid(row=0, column=0, columnspan=3, rowspan=1, pady=5, padx=5, sticky="new")

# Image
image_1 = customtkinter.CTkImage(dark_image=Image.open(r"E:\Internship\Common_resources\official_train_img\images\images\1-122700001-OCR-LF-C01.jpg"), size=(670, 400))
image_2 = customtkinter.CTkImage(dark_image=Image.open(r"E:\Internship\Common_resources\official_train_img\images\images\1-123053001-OCR-AS-B01.jpg"), size=(600, 350))

lframe = customtkinter.CTkFrame(root, width=450, fg_color='#2c2f33')
lframe.grid(row=1, column=0, columnspan=1, rowspan=1, pady=5, padx=5, sticky="nsew")
# lframe.rowconfigure(0, weight=1)
lframe.rowconfigure(1, weight=1)
lframe.columnconfigure(0, weight=1)

# status_label = customtkinter.CTkLabel(root, width=400, height=1)
tlframe = customtkinter.CTkFrame(lframe, fg_color='#2c2f33')
tlframe.grid(row=0, column=0, columnspan=1, rowspan=1, pady=5, padx=5, sticky="new")
tlframe.rowconfigure((0,1), weight=1)
tlframe.columnconfigure(0, weight=1)
tlframe.columnconfigure(1, weight=2)

status_label = customtkinter.CTkLabel(tlframe, text='STATUS', width=70, height=10, bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=20, weight="bold"))
status_label.grid(row=0, column=0, padx=5, pady=5, sticky="nsew")

status_display = customtkinter.CTkLabel(tlframe, text='TRUCK DETECTED', width=230, height=10, bg_color='#ffffff', corner_radius=20, font=customtkinter.CTkFont(size=20, weight="bold"), text_color='black')
status_display.grid(row=0, column=1, padx=5, pady=5, sticky="nsew")

license_plate = customtkinter.CTkLabel(tlframe, text='PLATE', width=70, height=10, bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=20, weight="bold"))
license_plate.grid(row=1, column=0, padx=5, pady=5, sticky="nsew")

plate_display = customtkinter.CTkLabel(tlframe, text='15C16188', width=230, height=10, bg_color='#ffffff', corner_radius=20, font=customtkinter.CTkFont(size=20, weight="bold"), text_color='black')
plate_display.grid(row=1, column=1, padx=5, pady=5, sticky="nsew")

blframe = customtkinter.CTkFrame(lframe, width=300, fg_color='#2c2f33', border_color='#7289da', border_width=2, corner_radius=0)
blframe.grid(row=1, column=0, columnspan=1, pady=5, padx=5, sticky="nsew")
blframe.rowconfigure((0,1), weight=1)
blframe.columnconfigure((0,1), weight=1)

rframe = customtkinter.CTkFrame(root, fg_color='#2c2f33')
rframe.grid(row=1, column=1, columnspan=1, rowspan=1, pady=5, padx=5, sticky="nsew")
rframe.columnconfigure(0, weight=1)
rframe.columnconfigure(1, weight=1)
# rframe.rowconfigure(0, weight=1)
rframe.rowconfigure(1, weight=1)

# Showing container 1 details
c1_frame = customtkinter.CTkFrame(rframe, width=450, fg_color='#2c2f33', border_color='#7289da', border_width=2, corner_radius=0)
c1_frame.grid(row=0, column=0, pady=5, padx=5)
c1_frame.rowconfigure(0, weight=1)
c1_frame.rowconfigure(1, weight=3)
c1_frame.rowconfigure(2, weight=3)
c1_frame.columnconfigure(0, weight=1)


c1_image = customtkinter.CTkLabel(c1_frame, text='', image=image_1, bg_color= '#7289da', anchor='s')
c1_image.grid(row=0, column=0, padx=5, pady=5, sticky="n")

c1_label = customtkinter.CTkLabel(c1_image, width=150, text='FRONT', text_color='#ffffff', bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=15, weight="bold"))
# c1_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")
c1_label.place(relx=1, rely=1, x=0, y=0,anchor="se")

# c1_detail = customtkinter.CTkLabel(c1_frame, text='DETAILS', bg_color= '#2c2f33', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
# c1_detail.grid(row=2, column=0, padx=5, pady=5, sticky="n")

# Showing container 2 details
c2_frame = customtkinter.CTkFrame(rframe, fg_color='#2c2f33', border_color='#7289da', border_width=2, corner_radius=0)
c2_frame.grid(row=0, column=1, pady=5, padx=5)
c2_frame.rowconfigure(0, weight=1)
c2_frame.rowconfigure(1, weight=3)
c2_frame.rowconfigure(2, weight=3)
c2_frame.columnconfigure(0, weight=1)


c2_image = customtkinter.CTkLabel(c2_frame, text='', image=image_1, bg_color= '#7289da', anchor='s')
c2_image.grid(row=1, column=0, padx=5, pady=5, sticky="n")

c2_label = customtkinter.CTkLabel(c2_image, width=150, text='REAR', text_color='#ffffff', bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=15, weight="bold"))
# c2_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")
c2_label.place(relx=1, rely=1, x=0, y=0,anchor="se")

# Showing container 3 details
c3_frame = customtkinter.CTkFrame(rframe, width=350, fg_color='#2c2f33', border_color='#7289da', border_width=2, corner_radius=0)
c3_frame.grid(row=1, column=0, pady=5, padx=5)
c3_frame.rowconfigure(0, weight=1)
c3_frame.rowconfigure(1, weight=3)
c3_frame.rowconfigure(2, weight=3)
c3_frame.columnconfigure(0, weight=1)


c3_image = customtkinter.CTkLabel(c3_frame, text='', image=image_1, bg_color= '#7289da', anchor='s')
c3_image.grid(row=1, column=0, padx=5, pady=5, sticky="n")

c3_label = customtkinter.CTkLabel(c3_image, width=150, text='CONTAINER 1', text_color='#ffffff', bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=15, weight="bold"))
# c3_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")
c3_label.place(relx=1, rely=1, x=0, y=0,anchor="se")

# Showing container 4 details
c4_frame = customtkinter.CTkFrame(rframe, width=450, fg_color='#2c2f33', border_color='#7289da', border_width=2, corner_radius=0)
c4_frame.grid(row=1, column=1, pady=5, padx=5)
c4_frame.rowconfigure(0, weight=1)
c4_frame.rowconfigure(1, weight=3)
c4_frame.rowconfigure(2, weight=3)
c4_frame.columnconfigure(0, weight=1)


c4_image = customtkinter.CTkLabel(c4_frame, text='', image=image_1, bg_color= '#7289da', anchor='s')
c4_image.grid(row=1, column=0, padx=5, pady=5, sticky="n")

c4_label = customtkinter.CTkLabel(c4_image, width=150, text='CONTAINER 2', text_color='#ffffff', bg_color= '#7289da', corner_radius=20, font=customtkinter.CTkFont(size=15, weight="bold"))
# c4_label.grid(row=0, column=0, padx=5, pady=5, sticky="new")
c4_label.place(relx=1, rely=1, x=0, y=0,anchor="se")

# c4_detail = customtkinter.CTkLabel(c4_frame, text='DETAILS', bg_color= '#2c2f33', corner_radius=20, font=customtkinter.CTkFont(size=30, weight="bold"))
# c4_detail.grid(row=2, column=0, padx=5, pady=5, sticky="n")

root.mainloop()
